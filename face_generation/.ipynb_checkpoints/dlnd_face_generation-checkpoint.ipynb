# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function

    inputs_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='input_real')
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    lr_rate = tf.placeholder(tf.float32)
    
    return (inputs_real, inputs_z, lr_rate)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def lrelu(x, alpha=0.2):
    """Leaky ReLu implementation"""
    return tf.maximum(alpha * x, x)

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    
    alpha=0.2
    input_shape = images.get_shape().as_list()[2]
    final_shape = input_shape // 4
    flat_shape = (-1, final_shape * final_shape * 128)
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input as image batch
        net = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        net = tf.maximum(alpha * net, net)
        # First convolution with 64 filters
        
        net = tf.layers.conv2d(net, 128, 5, strides=2, padding='same')
        net = tf.layers.batch_normalization(net, training=True)
        net = lrelu(net)
        # Second convolution with 128 filters
        
        #net = tf.layers.conv2d(net, 512, 5, strides=2, padding='same')
        #net = tf.layers.batch_normalization(net, training=True)
        #net = lrelu(net)
        # Second convolution with 512 filters
        
        # Flatten layers
        net = tf.reshape(net, flat_shape)
        logits = tf.layers.dense(net, 1)
        outputs = tf.sigmoid(logits)
        
        
    return (outputs, logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    
    alpha=0.2
    reuse=not is_train
    with tf.variable_scope('generator', reuse=reuse):
        # Flat layer
        net = tf.layers.dense(z, 7*7*512)
        net = tf.reshape(net, (-1, 7, 7, 512))
        net = tf.layers.batch_normalization(net, training=is_train)
        net = lrelu(net)
        
        # Deconvolution for 256 filters 14 X 14 shape
        net = tf.layers.conv2d_transpose(net, 256, 5, strides=2, padding='same')
        net = tf.layers.batch_normalization(net, training=is_train)
        net = lrelu(net)
        
        # Deconvolution for 128 filters 14 X 14 shape
        net = tf.layers.conv2d_transpose(net, 128, 5, strides=1, padding='same')
        net = tf.layers.batch_normalization(net, training=is_train)
        net = lrelu(net)
        
        # Deconvolution for out_channel_dim filters 28 X 28 shape
        net = tf.layers.conv2d_transpose(net, out_channel_dim, 5, strides=2, padding='same')
        out = tf.tanh(net)
        
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    
    g_model = generator(input_z, out_channel_dim, is_train=True)
    (d_model_real, d_logits_real) = discriminator(input_real)
    (d_model_fake, d_logits_fake) = discriminator(g_model, reuse=True)
    
    # Discriminator loss
    d_labels_real = tf.ones_like(d_model_real)
    d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=d_labels_real))
    d_labels_fake = tf.zeros_like(d_model_fake)
    d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=d_labels_fake))
    d_loss = d_loss_real + d_loss_fake
    
    # Generator loss
    g_labels = tf.ones_like(d_model_fake)
    g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=g_labels))
    
    return (d_loss, g_loss)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    
    tr_vars = tf.trainable_variables()
    g_vars = [var for var in tr_vars if var.name.startswith('generator')]
    d_vars = [var for var in tr_vars if var.name.startswith('discriminator')]
    
    # I think one could use tf.get_collection((tf.GraphKeys.TRAINABLE_VARIABLES, ...) 
    # but this one (list comprehension) seems more self explanatory
    
    # Training optimizers for appropriated variables
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        genr_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
        disc_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    
    return (disc_train_opt, genr_train_opt)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    
    out_channel_dim = data_shape[3]
    (input_real, input_z, lr_rate) = model_inputs(data_shape[1], data_shape[2], out_channel_dim, z_dim)
    (d_loss, g_loss) = model_loss(input_real, input_z, out_channel_dim)
    (d_opt, g_opt) = model_opt(d_loss, g_loss, lr_rate, beta1)
    
    saver = tf.train.Saver()
    sample_size = 25
    file_prfx = 'celeb_' if data_image_mode == 'RGB' else 'mnist_'
    chkp_file_path = './checkpoints/' + file_prfx + 'generator.ckpt'

    steps = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                
                steps += 1
                
                # Normalize images
                norm_batch_images = batch_images * 2
                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                train_feed_dict = {input_real: norm_batch_images, input_z: batch_z, lr_rate: learning_rate}
                # Run optimizers
                # For discriminator
                _ = sess.run(d_opt, feed_dict=train_feed_dict)
                # For generator
                for _ in range(2):
                    _ = sess.run(g_opt, feed_dict=train_feed_dict)
                
                if steps % 10 == 0:
                    # Get the losses and print them out
                    train_loss_d = d_loss.eval({input_real: norm_batch_images, input_z: batch_z})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}...".format(epoch_i + 1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                if steps % 100 == 0:  
                    # Show samples
                    show_generator_output(sess, sample_size, input_z, out_channel_dim, data_image_mode)
        saver.save(sess, chkp_file_path)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 32
z_dim = 100
learning_rate = 0.0008
beta1 = 0.3


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 2.2484... Generator Loss: 0.1454
# Epoch 1/2... Discriminator Loss: 1.4770... Generator Loss: 0.8120
# Epoch 1/2... Discriminator Loss: 0.7098... Generator Loss: 0.8043
# Epoch 1/2... Discriminator Loss: 0.2661... Generator Loss: 1.6967
# Epoch 1/2... Discriminator Loss: 0.1408... Generator Loss: 2.2197
# Epoch 1/2... Discriminator Loss: 0.0731... Generator Loss: 2.7951
# Epoch 1/2... Discriminator Loss: 0.0492... Generator Loss: 3.2744
# Epoch 1/2... Discriminator Loss: 5.2968... Generator Loss: 0.3146
# Epoch 1/2... Discriminator Loss: 2.7637... Generator Loss: 0.1201
# Epoch 1/2... Discriminator Loss: 2.1769... Generator Loss: 0.2731
# Epoch 1/2... Discriminator Loss: 2.6861... Generator Loss: 0.3449
# Epoch 1/2... Discriminator Loss: 2.1295... Generator Loss: 0.5205
# Epoch 1/2... Discriminator Loss: 2.1377... Generator Loss: 0.6651
# Epoch 1/2... Discriminator Loss: 2.0090... Generator Loss: 0.2355
# Epoch 1/2... Discriminator Loss: 1.9133... Generator Loss: 0.2725
# Epoch 1/2... Discriminator Loss: 1.8176... Generator Loss: 0.5498
# Epoch 1/2... Discriminator Loss: 1.9660... Generator Loss: 0.2499
# Epoch 1/2... Discriminator Loss: 1.9355... Generator Loss: 0.2533
# Epoch 1/2... Discriminator Loss: 1.5811... Generator Loss: 0.5894
# Epoch 1/2... Discriminator Loss: 1.9288... Generator Loss: 0.5716
# Epoch 1/2... Discriminator Loss: 1.8252... Generator Loss: 0.3106
# Epoch 1/2... Discriminator Loss: 1.6724... Generator Loss: 0.4921
# Epoch 1/2... Discriminator Loss: 1.7772... Generator Loss: 0.2750
# Epoch 1/2... Discriminator Loss: 1.8006... Generator Loss: 0.2974
# Epoch 1/2... Discriminator Loss: 1.6483... Generator Loss: 0.3510
# Epoch 1/2... Discriminator Loss: 1.7017... Generator Loss: 0.9020
# Epoch 1/2... Discriminator Loss: 1.6365... Generator Loss: 0.6356
# Epoch 1/2... Discriminator Loss: 1.6582... Generator Loss: 0.4650
# Epoch 1/2... Discriminator Loss: 1.8737... Generator Loss: 0.6062
# Epoch 1/2... Discriminator Loss: 1.9500... Generator Loss: 1.0857
# Epoch 1/2... Discriminator Loss: 2.0057... Generator Loss: 0.1985
# Epoch 1/2... Discriminator Loss: 1.7909... Generator Loss: 0.2717
# Epoch 1/2... Discriminator Loss: 1.7172... Generator Loss: 0.3371
# Epoch 1/2... Discriminator Loss: 1.7621... Generator Loss: 0.2677
# Epoch 1/2... Discriminator Loss: 1.6674... Generator Loss: 0.5856
# Epoch 1/2... Discriminator Loss: 2.0318... Generator Loss: 0.1984
# Epoch 1/2... Discriminator Loss: 1.6165... Generator Loss: 0.5050
# Epoch 1/2... Discriminator Loss: 1.8902... Generator Loss: 0.8734
# Epoch 1/2... Discriminator Loss: 1.8934... Generator Loss: 0.7556
# Epoch 1/2... Discriminator Loss: 1.6764... Generator Loss: 0.6134
# Epoch 1/2... Discriminator Loss: 1.6983... Generator Loss: 0.7377
# Epoch 1/2... Discriminator Loss: 1.5880... Generator Loss: 0.3999
# Epoch 1/2... Discriminator Loss: 1.9341... Generator Loss: 0.1941
# Epoch 1/2... Discriminator Loss: 1.8889... Generator Loss: 0.2470
# Epoch 1/2... Discriminator Loss: 1.8511... Generator Loss: 0.2552
# Epoch 1/2... Discriminator Loss: 2.2200... Generator Loss: 0.1493
# Epoch 1/2... Discriminator Loss: 1.5744... Generator Loss: 0.7038
# Epoch 1/2... Discriminator Loss: 1.8362... Generator Loss: 0.2430
# Epoch 1/2... Discriminator Loss: 1.6634... Generator Loss: 0.4065
# Epoch 1/2... Discriminator Loss: 1.6925... Generator Loss: 0.3801
# Epoch 1/2... Discriminator Loss: 1.7092... Generator Loss: 1.0404
# Epoch 1/2... Discriminator Loss: 1.5618... Generator Loss: 0.5697
# Epoch 1/2... Discriminator Loss: 1.9385... Generator Loss: 0.9243
# Epoch 1/2... Discriminator Loss: 1.5727... Generator Loss: 0.5347
# Epoch 1/2... Discriminator Loss: 1.8007... Generator Loss: 0.7954
# Epoch 1/2... Discriminator Loss: 1.4949... Generator Loss: 0.7979
# Epoch 1/2... Discriminator Loss: 1.5222... Generator Loss: 0.6056
# Epoch 1/2... Discriminator Loss: 1.4731... Generator Loss: 0.5315
# Epoch 1/2... Discriminator Loss: 1.7636... Generator Loss: 0.2560
# Epoch 1/2... Discriminator Loss: 1.7083... Generator Loss: 0.3001
# Epoch 1/2... Discriminator Loss: 1.6363... Generator Loss: 0.3955
# Epoch 1/2... Discriminator Loss: 1.7428... Generator Loss: 0.2936
# Epoch 1/2... Discriminator Loss: 1.5910... Generator Loss: 0.4454
# Epoch 1/2... Discriminator Loss: 1.9284... Generator Loss: 0.2337
# Epoch 1/2... Discriminator Loss: 1.6939... Generator Loss: 0.3205
# Epoch 1/2... Discriminator Loss: 1.5060... Generator Loss: 0.8007
# Epoch 1/2... Discriminator Loss: 1.6650... Generator Loss: 0.6711
# Epoch 1/2... Discriminator Loss: 1.5380... Generator Loss: 0.4856
# Epoch 1/2... Discriminator Loss: 1.6669... Generator Loss: 0.8223
# Epoch 1/2... Discriminator Loss: 1.5093... Generator Loss: 0.6813
# Epoch 1/2... Discriminator Loss: 1.7334... Generator Loss: 0.3314
# Epoch 1/2... Discriminator Loss: 2.1926... Generator Loss: 0.1526
# Epoch 1/2... Discriminator Loss: 1.4553... Generator Loss: 0.7352
# Epoch 1/2... Discriminator Loss: 1.5697... Generator Loss: 0.4786
# Epoch 1/2... Discriminator Loss: 1.6247... Generator Loss: 0.4200
# Epoch 1/2... Discriminator Loss: 1.9359... Generator Loss: 0.1931
# Epoch 1/2... Discriminator Loss: 1.7562... Generator Loss: 0.2661
# Epoch 1/2... Discriminator Loss: 1.8459... Generator Loss: 0.2428
# Epoch 1/2... Discriminator Loss: 1.7733... Generator Loss: 0.2481
# Epoch 1/2... Discriminator Loss: 1.6524... Generator Loss: 0.2865
# Epoch 1/2... Discriminator Loss: 1.5067... Generator Loss: 0.4710
# Epoch 1/2... Discriminator Loss: 1.5991... Generator Loss: 0.3644
# Epoch 1/2... Discriminator Loss: 1.5761... Generator Loss: 0.4176
# Epoch 1/2... Discriminator Loss: 1.4612... Generator Loss: 0.7533
# Epoch 1/2... Discriminator Loss: 1.6057... Generator Loss: 1.0444
# Epoch 1/2... Discriminator Loss: 1.5354... Generator Loss: 0.4511
# Epoch 1/2... Discriminator Loss: 1.4632... Generator Loss: 0.4553
# Epoch 1/2... Discriminator Loss: 2.2080... Generator Loss: 0.1439
# Epoch 1/2... Discriminator Loss: 1.5365... Generator Loss: 0.6203
# Epoch 1/2... Discriminator Loss: 1.5769... Generator Loss: 0.8298
# Epoch 1/2... Discriminator Loss: 1.7726... Generator Loss: 1.0308
# Epoch 1/2... Discriminator Loss: 1.4526... Generator Loss: 0.4528
# Epoch 1/2... Discriminator Loss: 1.6300... Generator Loss: 0.3027
# Epoch 1/2... Discriminator Loss: 1.5995... Generator Loss: 0.4454
# Epoch 1/2... Discriminator Loss: 1.6759... Generator Loss: 0.3451
# Epoch 1/2... Discriminator Loss: 1.6732... Generator Loss: 0.2998
# Epoch 1/2... Discriminator Loss: 1.7140... Generator Loss: 0.3034
# Epoch 1/2... Discriminator Loss: 1.5748... Generator Loss: 0.4327
# Epoch 1/2... Discriminator Loss: 1.3980... Generator Loss: 0.5789
# Epoch 1/2... Discriminator Loss: 1.5254... Generator Loss: 0.7434
# Epoch 1/2... Discriminator Loss: 1.4501... Generator Loss: 0.7947
# Epoch 1/2... Discriminator Loss: 1.4817... Generator Loss: 1.0395
# Epoch 1/2... Discriminator Loss: 1.4464... Generator Loss: 0.7439
# Epoch 1/2... Discriminator Loss: 1.5384... Generator Loss: 0.4059
# Epoch 1/2... Discriminator Loss: 1.7713... Generator Loss: 0.2925
# Epoch 1/2... Discriminator Loss: 1.3831... Generator Loss: 0.7081
# Epoch 1/2... Discriminator Loss: 1.5939... Generator Loss: 0.9913
# Epoch 1/2... Discriminator Loss: 1.5417... Generator Loss: 0.3156
# Epoch 1/2... Discriminator Loss: 1.5137... Generator Loss: 0.6177
# Epoch 1/2... Discriminator Loss: 1.4594... Generator Loss: 0.6187
# Epoch 1/2... Discriminator Loss: 1.8845... Generator Loss: 0.2108
# Epoch 1/2... Discriminator Loss: 1.5443... Generator Loss: 0.4093
# Epoch 1/2... Discriminator Loss: 1.3889... Generator Loss: 0.8288
# Epoch 1/2... Discriminator Loss: 1.5429... Generator Loss: 0.4326
# Epoch 1/2... Discriminator Loss: 1.3368... Generator Loss: 0.7702
# Epoch 1/2... Discriminator Loss: 1.8682... Generator Loss: 0.2427
# Epoch 1/2... Discriminator Loss: 1.6443... Generator Loss: 0.3305
# Epoch 1/2... Discriminator Loss: 1.8950... Generator Loss: 0.2202
# Epoch 1/2... Discriminator Loss: 1.5070... Generator Loss: 0.6384
# Epoch 1/2... Discriminator Loss: 1.3756... Generator Loss: 0.5405
# Epoch 1/2... Discriminator Loss: 1.7358... Generator Loss: 0.2974
# Epoch 1/2... Discriminator Loss: 1.5410... Generator Loss: 0.5472
# Epoch 1/2... Discriminator Loss: 1.4916... Generator Loss: 0.8714
# Epoch 1/2... Discriminator Loss: 1.4609... Generator Loss: 0.5699
# Epoch 1/2... Discriminator Loss: 1.3822... Generator Loss: 0.7901
# Epoch 1/2... Discriminator Loss: 1.4185... Generator Loss: 0.5176
# Epoch 1/2... Discriminator Loss: 1.8752... Generator Loss: 0.2345
# Epoch 1/2... Discriminator Loss: 1.5581... Generator Loss: 0.3714
# Epoch 1/2... Discriminator Loss: 1.5848... Generator Loss: 0.3019
# Epoch 1/2... Discriminator Loss: 1.5109... Generator Loss: 0.5074
# Epoch 1/2... Discriminator Loss: 1.5336... Generator Loss: 0.5983
# Epoch 1/2... Discriminator Loss: 1.3877... Generator Loss: 0.4905
# Epoch 1/2... Discriminator Loss: 1.6150... Generator Loss: 0.3265
# Epoch 1/2... Discriminator Loss: 1.3248... Generator Loss: 0.8311
# Epoch 1/2... Discriminator Loss: 1.5823... Generator Loss: 0.7129
# Epoch 1/2... Discriminator Loss: 1.6340... Generator Loss: 0.3235
# Epoch 1/2... Discriminator Loss: 1.5689... Generator Loss: 0.3406
# Epoch 1/2... Discriminator Loss: 1.5714... Generator Loss: 0.4406
# Epoch 1/2... Discriminator Loss: 1.5234... Generator Loss: 0.6414
# Epoch 1/2... Discriminator Loss: 1.6634... Generator Loss: 0.3044
# Epoch 1/2... Discriminator Loss: 1.3958... Generator Loss: 0.5255
# Epoch 1/2... Discriminator Loss: 1.5236... Generator Loss: 0.5316
# Epoch 1/2... Discriminator Loss: 1.9900... Generator Loss: 0.9098
# Epoch 1/2... Discriminator Loss: 1.3795... Generator Loss: 0.5667
# Epoch 1/2... Discriminator Loss: 1.3908... Generator Loss: 0.5016
# Epoch 1/2... Discriminator Loss: 1.5811... Generator Loss: 0.3940
# Epoch 1/2... Discriminator Loss: 1.7278... Generator Loss: 0.2666
# Epoch 1/2... Discriminator Loss: 1.3309... Generator Loss: 0.5113
# Epoch 1/2... Discriminator Loss: 1.6037... Generator Loss: 0.2934
# Epoch 1/2... Discriminator Loss: 1.7017... Generator Loss: 0.2951
# Epoch 1/2... Discriminator Loss: 1.3579... Generator Loss: 1.0629
# Epoch 1/2... Discriminator Loss: 1.4313... Generator Loss: 0.7758
# Epoch 1/2... Discriminator Loss: 1.4135... Generator Loss: 0.8807
# Epoch 1/2... Discriminator Loss: 1.5106... Generator Loss: 0.4151
# Epoch 1/2... Discriminator Loss: 2.5220... Generator Loss: 0.1040
# Epoch 1/2... Discriminator Loss: 1.5178... Generator Loss: 0.4831
# Epoch 1/2... Discriminator Loss: 1.4950... Generator Loss: 0.8707
# Epoch 1/2... Discriminator Loss: 1.4926... Generator Loss: 0.5273
# Epoch 1/2... Discriminator Loss: 1.4066... Generator Loss: 0.5292
# Epoch 1/2... Discriminator Loss: 1.4357... Generator Loss: 0.7228
# Epoch 1/2... Discriminator Loss: 1.4139... Generator Loss: 0.4903
# Epoch 1/2... Discriminator Loss: 1.2522... Generator Loss: 0.7681
# Epoch 1/2... Discriminator Loss: 1.4545... Generator Loss: 0.6999
# Epoch 1/2... Discriminator Loss: 1.5286... Generator Loss: 0.5628
# Epoch 1/2... Discriminator Loss: 1.3732... Generator Loss: 0.7966
# Epoch 1/2... Discriminator Loss: 1.4480... Generator Loss: 0.6966
# Epoch 1/2... Discriminator Loss: 1.4466... Generator Loss: 0.4679
# Epoch 1/2... Discriminator Loss: 1.6374... Generator Loss: 0.3134
# Epoch 1/2... Discriminator Loss: 1.6412... Generator Loss: 0.3073
# Epoch 1/2... Discriminator Loss: 1.5721... Generator Loss: 0.3504
# Epoch 1/2... Discriminator Loss: 2.2138... Generator Loss: 0.1480
# Epoch 1/2... Discriminator Loss: 1.4454... Generator Loss: 0.5021
# Epoch 1/2... Discriminator Loss: 1.4907... Generator Loss: 0.3696
# Epoch 1/2... Discriminator Loss: 2.0211... Generator Loss: 0.1666
# Epoch 1/2... Discriminator Loss: 1.3849... Generator Loss: 1.1024
# Epoch 1/2... Discriminator Loss: 1.3498... Generator Loss: 1.0029
# Epoch 1/2... Discriminator Loss: 1.4894... Generator Loss: 0.4653
# Epoch 1/2... Discriminator Loss: 1.3675... Generator Loss: 1.0697
# Epoch 1/2... Discriminator Loss: 1.2638... Generator Loss: 0.6442
# Epoch 1/2... Discriminator Loss: 1.5803... Generator Loss: 0.3498
# Epoch 1/2... Discriminator Loss: 1.7487... Generator Loss: 0.2719
# Epoch 1/2... Discriminator Loss: 1.8916... Generator Loss: 1.1550
# Epoch 1/2... Discriminator Loss: 1.3316... Generator Loss: 0.6374
# Epoch 1/2... Discriminator Loss: 1.4528... Generator Loss: 0.4689
# Epoch 1/2... Discriminator Loss: 1.3462... Generator Loss: 0.5458
# Epoch 1/2... Discriminator Loss: 1.5203... Generator Loss: 0.6488
# Epoch 1/2... Discriminator Loss: 1.7869... Generator Loss: 0.2473
# Epoch 2/2... Discriminator Loss: 1.6529... Generator Loss: 0.2988
# Epoch 2/2... Discriminator Loss: 1.3218... Generator Loss: 0.5851
# Epoch 2/2... Discriminator Loss: 1.8211... Generator Loss: 0.2302
# Epoch 2/2... Discriminator Loss: 1.4886... Generator Loss: 0.9463
# Epoch 2/2... Discriminator Loss: 1.4223... Generator Loss: 0.5258
# Epoch 2/2... Discriminator Loss: 1.8438... Generator Loss: 0.2286
# Epoch 2/2... Discriminator Loss: 1.6270... Generator Loss: 0.3550
# Epoch 2/2... Discriminator Loss: 1.5186... Generator Loss: 0.5448
# Epoch 2/2... Discriminator Loss: 1.9970... Generator Loss: 0.1833
# Epoch 2/2... Discriminator Loss: 1.4740... Generator Loss: 0.3618
# Epoch 2/2... Discriminator Loss: 1.3001... Generator Loss: 0.5861
# Epoch 2/2... Discriminator Loss: 1.5950... Generator Loss: 1.0679
# Epoch 2/2... Discriminator Loss: 1.4084... Generator Loss: 0.8368
# Epoch 2/2... Discriminator Loss: 1.4443... Generator Loss: 0.3648
# Epoch 2/2... Discriminator Loss: 1.4195... Generator Loss: 0.3968
# Epoch 2/2... Discriminator Loss: 1.5232... Generator Loss: 0.4237
# Epoch 2/2... Discriminator Loss: 1.6274... Generator Loss: 0.3007
# Epoch 2/2... Discriminator Loss: 1.2237... Generator Loss: 0.7835
# Epoch 2/2... Discriminator Loss: 1.6916... Generator Loss: 0.2516
# Epoch 2/2... Discriminator Loss: 2.0688... Generator Loss: 0.1491
# Epoch 2/2... Discriminator Loss: 1.7977... Generator Loss: 0.2455
# Epoch 2/2... Discriminator Loss: 1.2199... Generator Loss: 1.0662
# Epoch 2/2... Discriminator Loss: 1.5273... Generator Loss: 0.6216
# Epoch 2/2... Discriminator Loss: 1.6233... Generator Loss: 1.2406
# Epoch 2/2... Discriminator Loss: 1.3019... Generator Loss: 0.6815
# Epoch 2/2... Discriminator Loss: 1.4541... Generator Loss: 1.2035
# Epoch 2/2... Discriminator Loss: 1.2114... Generator Loss: 0.5440
# Epoch 2/2... Discriminator Loss: 1.2691... Generator Loss: 0.5583
# Epoch 2/2... Discriminator Loss: 3.6369... Generator Loss: 2.3526
# Epoch 2/2... Discriminator Loss: 1.3459... Generator Loss: 0.8136
# Epoch 2/2... Discriminator Loss: 1.3239... Generator Loss: 0.4984
# Epoch 2/2... Discriminator Loss: 1.6117... Generator Loss: 1.4220
# Epoch 2/2... Discriminator Loss: 1.4784... Generator Loss: 0.4721
# Epoch 2/2... Discriminator Loss: 1.3781... Generator Loss: 0.5195
# Epoch 2/2... Discriminator Loss: 1.2229... Generator Loss: 0.6001
# Epoch 2/2... Discriminator Loss: 1.6832... Generator Loss: 1.4463
# Epoch 2/2... Discriminator Loss: 1.6447... Generator Loss: 0.2904
# Epoch 2/2... Discriminator Loss: 1.5118... Generator Loss: 0.3313
# Epoch 2/2... Discriminator Loss: 1.3308... Generator Loss: 0.6049
# Epoch 2/2... Discriminator Loss: 1.7313... Generator Loss: 0.2516
# Epoch 2/2... Discriminator Loss: 1.2194... Generator Loss: 0.5607
# Epoch 2/2... Discriminator Loss: 1.9841... Generator Loss: 0.1805
# Epoch 2/2... Discriminator Loss: 1.4767... Generator Loss: 0.3696
# Epoch 2/2... Discriminator Loss: 1.2929... Generator Loss: 0.8708
# Epoch 2/2... Discriminator Loss: 2.3766... Generator Loss: 0.1437
# Epoch 2/2... Discriminator Loss: 1.2195... Generator Loss: 0.7489
# Epoch 2/2... Discriminator Loss: 1.7910... Generator Loss: 0.2465
# Epoch 2/2... Discriminator Loss: 1.1987... Generator Loss: 0.8413
# Epoch 2/2... Discriminator Loss: 1.3741... Generator Loss: 0.5020
# Epoch 2/2... Discriminator Loss: 1.4343... Generator Loss: 0.3672
# Epoch 2/2... Discriminator Loss: 1.2703... Generator Loss: 0.5288
# Epoch 2/2... Discriminator Loss: 1.6124... Generator Loss: 0.2998
# Epoch 2/2... Discriminator Loss: 1.8123... Generator Loss: 0.2294
# Epoch 2/2... Discriminator Loss: 1.7236... Generator Loss: 0.2774
# Epoch 2/2... Discriminator Loss: 1.1406... Generator Loss: 1.1308
# Epoch 2/2... Discriminator Loss: 1.5171... Generator Loss: 0.3621
# Epoch 2/2... Discriminator Loss: 1.5288... Generator Loss: 0.3354
# Epoch 2/2... Discriminator Loss: 1.4942... Generator Loss: 0.4397
# Epoch 2/2... Discriminator Loss: 1.5305... Generator Loss: 0.3521
# Epoch 2/2... Discriminator Loss: 1.7015... Generator Loss: 0.6619
# Epoch 2/2... Discriminator Loss: 1.4652... Generator Loss: 0.4122
# Epoch 2/2... Discriminator Loss: 1.2632... Generator Loss: 0.6363
# Epoch 2/2... Discriminator Loss: 1.1969... Generator Loss: 0.5690
# Epoch 2/2... Discriminator Loss: 1.6108... Generator Loss: 1.2482
# Epoch 2/2... Discriminator Loss: 1.2695... Generator Loss: 0.5701
# Epoch 2/2... Discriminator Loss: 1.2747... Generator Loss: 0.9595
# Epoch 2/2... Discriminator Loss: 1.2457... Generator Loss: 0.5088
# Epoch 2/2... Discriminator Loss: 1.2509... Generator Loss: 0.8087
# Epoch 2/2... Discriminator Loss: 1.7323... Generator Loss: 0.2411
# Epoch 2/2... Discriminator Loss: 1.7300... Generator Loss: 0.2662
# Epoch 2/2... Discriminator Loss: 1.6334... Generator Loss: 0.2958
# Epoch 2/2... Discriminator Loss: 1.3754... Generator Loss: 0.5775
# Epoch 2/2... Discriminator Loss: 1.0247... Generator Loss: 0.7334
# Epoch 2/2... Discriminator Loss: 1.5281... Generator Loss: 0.3234
# Epoch 2/2... Discriminator Loss: 1.2901... Generator Loss: 0.5613
# Epoch 2/2... Discriminator Loss: 3.1507... Generator Loss: 2.4107
# Epoch 2/2... Discriminator Loss: 1.7609... Generator Loss: 0.2540
# Epoch 2/2... Discriminator Loss: 1.3718... Generator Loss: 0.6969
# Epoch 2/2... Discriminator Loss: 1.3612... Generator Loss: 0.4234
# Epoch 2/2... Discriminator Loss: 1.3697... Generator Loss: 0.4175
# Epoch 2/2... Discriminator Loss: 1.3407... Generator Loss: 0.3714
# Epoch 2/2... Discriminator Loss: 1.3702... Generator Loss: 0.7115
# Epoch 2/2... Discriminator Loss: 1.7238... Generator Loss: 0.2554
# Epoch 2/2... Discriminator Loss: 1.3035... Generator Loss: 0.4758
# Epoch 2/2... Discriminator Loss: 2.8019... Generator Loss: 2.7114
# Epoch 2/2... Discriminator Loss: 1.1018... Generator Loss: 0.9002
# Epoch 2/2... Discriminator Loss: 1.2189... Generator Loss: 1.1786
# Epoch 2/2... Discriminator Loss: 1.2159... Generator Loss: 0.5833
# Epoch 2/2... Discriminator Loss: 1.7762... Generator Loss: 0.2347
# Epoch 2/2... Discriminator Loss: 1.8331... Generator Loss: 0.2212
# Epoch 2/2... Discriminator Loss: 1.5320... Generator Loss: 0.3532
# Epoch 2/2... Discriminator Loss: 1.6169... Generator Loss: 0.2854
# Epoch 2/2... Discriminator Loss: 1.6441... Generator Loss: 0.2856
# Epoch 2/2... Discriminator Loss: 1.3755... Generator Loss: 0.4008
# Epoch 2/2... Discriminator Loss: 3.3054... Generator Loss: 0.0507
# Epoch 2/2... Discriminator Loss: 1.3053... Generator Loss: 0.5349
# Epoch 2/2... Discriminator Loss: 1.1212... Generator Loss: 0.6007
# Epoch 2/2... Discriminator Loss: 1.0982... Generator Loss: 1.1677
# Epoch 2/2... Discriminator Loss: 1.2402... Generator Loss: 0.5262
# Epoch 2/2... Discriminator Loss: 1.1354... Generator Loss: 1.0338
# Epoch 2/2... Discriminator Loss: 1.5913... Generator Loss: 0.3333
# Epoch 2/2... Discriminator Loss: 1.4818... Generator Loss: 0.3399
# Epoch 2/2... Discriminator Loss: 1.4232... Generator Loss: 0.4178
# Epoch 2/2... Discriminator Loss: 1.1632... Generator Loss: 0.5418
# Epoch 2/2... Discriminator Loss: 1.5218... Generator Loss: 0.3361
# Epoch 2/2... Discriminator Loss: 2.3075... Generator Loss: 0.1278
# Epoch 2/2... Discriminator Loss: 1.4144... Generator Loss: 0.4266
# Epoch 2/2... Discriminator Loss: 1.3409... Generator Loss: 0.5795
# Epoch 2/2... Discriminator Loss: 1.1345... Generator Loss: 0.6571
# Epoch 2/2... Discriminator Loss: 2.0149... Generator Loss: 0.1773
# Epoch 2/2... Discriminator Loss: 1.3362... Generator Loss: 0.7714
# Epoch 2/2... Discriminator Loss: 1.7553... Generator Loss: 0.2244
# Epoch 2/2... Discriminator Loss: 1.5267... Generator Loss: 0.3202
# Epoch 2/2... Discriminator Loss: 1.4659... Generator Loss: 0.4683
# Epoch 2/2... Discriminator Loss: 1.4647... Generator Loss: 0.3472
# Epoch 2/2... Discriminator Loss: 1.4364... Generator Loss: 0.4305
# Epoch 2/2... Discriminator Loss: 1.5057... Generator Loss: 0.4095
# Epoch 2/2... Discriminator Loss: 1.2725... Generator Loss: 0.6098
# Epoch 2/2... Discriminator Loss: 1.6020... Generator Loss: 0.5462
# Epoch 2/2... Discriminator Loss: 1.0067... Generator Loss: 1.1756
# Epoch 2/2... Discriminator Loss: 1.1152... Generator Loss: 0.6707
# Epoch 2/2... Discriminator Loss: 1.5372... Generator Loss: 0.3217
# Epoch 2/2... Discriminator Loss: 1.3359... Generator Loss: 0.5333
# Epoch 2/2... Discriminator Loss: 1.4575... Generator Loss: 0.3887
# Epoch 2/2... Discriminator Loss: 1.5858... Generator Loss: 0.3248
# Epoch 2/2... Discriminator Loss: 1.4459... Generator Loss: 0.6133
# Epoch 2/2... Discriminator Loss: 1.9681... Generator Loss: 0.1976
# Epoch 2/2... Discriminator Loss: 1.3674... Generator Loss: 0.5153
# Epoch 2/2... Discriminator Loss: 1.2636... Generator Loss: 0.4991
# Epoch 2/2... Discriminator Loss: 1.2344... Generator Loss: 1.5830
# Epoch 2/2... Discriminator Loss: 1.5784... Generator Loss: 0.3298
# Epoch 2/2... Discriminator Loss: 1.4953... Generator Loss: 0.3214
# Epoch 2/2... Discriminator Loss: 1.9512... Generator Loss: 0.2053
# Epoch 2/2... Discriminator Loss: 1.8498... Generator Loss: 0.2246
# Epoch 2/2... Discriminator Loss: 1.5693... Generator Loss: 0.3151
# Epoch 2/2... Discriminator Loss: 1.6451... Generator Loss: 0.2754
# Epoch 2/2... Discriminator Loss: 1.7379... Generator Loss: 0.2685
# Epoch 2/2... Discriminator Loss: 1.7982... Generator Loss: 0.2260
# Epoch 2/2... Discriminator Loss: 1.3854... Generator Loss: 1.1109
# Epoch 2/2... Discriminator Loss: 1.5542... Generator Loss: 0.3862
# Epoch 2/2... Discriminator Loss: 1.5480... Generator Loss: 0.3547
# Epoch 2/2... Discriminator Loss: 1.6064... Generator Loss: 0.3368
# Epoch 2/2... Discriminator Loss: 1.4005... Generator Loss: 0.4618
# Epoch 2/2... Discriminator Loss: 1.6369... Generator Loss: 0.2885
# Epoch 2/2... Discriminator Loss: 1.1809... Generator Loss: 1.0595
# Epoch 2/2... Discriminator Loss: 1.4260... Generator Loss: 0.4278
# Epoch 2/2... Discriminator Loss: 1.3626... Generator Loss: 1.6666
# Epoch 2/2... Discriminator Loss: 1.4280... Generator Loss: 1.3391
# Epoch 2/2... Discriminator Loss: 1.4391... Generator Loss: 0.4358
# Epoch 2/2... Discriminator Loss: 1.7864... Generator Loss: 0.2399
# Epoch 2/2... Discriminator Loss: 1.6021... Generator Loss: 0.3824
# Epoch 2/2... Discriminator Loss: 1.1559... Generator Loss: 0.6077
# Epoch 2/2... Discriminator Loss: 1.3297... Generator Loss: 0.5765
# Epoch 2/2... Discriminator Loss: 1.1046... Generator Loss: 1.0041
# Epoch 2/2... Discriminator Loss: 1.3171... Generator Loss: 0.5693
# Epoch 2/2... Discriminator Loss: 1.4538... Generator Loss: 0.3578
# Epoch 2/2... Discriminator Loss: 1.2837... Generator Loss: 1.1534
# Epoch 2/2... Discriminator Loss: 1.1927... Generator Loss: 0.7197
# Epoch 2/2... Discriminator Loss: 1.4356... Generator Loss: 0.9756
# Epoch 2/2... Discriminator Loss: 1.2941... Generator Loss: 0.5366
# Epoch 2/2... Discriminator Loss: 1.2366... Generator Loss: 0.5158
# Epoch 2/2... Discriminator Loss: 1.6590... Generator Loss: 0.2655
# Epoch 2/2... Discriminator Loss: 1.2366... Generator Loss: 0.4640
# Epoch 2/2... Discriminator Loss: 1.7027... Generator Loss: 0.2626
# Epoch 2/2... Discriminator Loss: 1.5471... Generator Loss: 0.3289
# Epoch 2/2... Discriminator Loss: 1.2324... Generator Loss: 1.3120
# Epoch 2/2... Discriminator Loss: 1.2332... Generator Loss: 0.5859
# Epoch 2/2... Discriminator Loss: 1.3353... Generator Loss: 0.7862
# Epoch 2/2... Discriminator Loss: 3.5166... Generator Loss: 3.2173
# Epoch 2/2... Discriminator Loss: 1.4212... Generator Loss: 0.4564
# Epoch 2/2... Discriminator Loss: 1.2788... Generator Loss: 0.6836
# Epoch 2/2... Discriminator Loss: 1.3256... Generator Loss: 0.4018
# Epoch 2/2... Discriminator Loss: 1.4246... Generator Loss: 0.3942
# Epoch 2/2... Discriminator Loss: 1.1948... Generator Loss: 0.6209
# Epoch 2/2... Discriminator Loss: 1.4687... Generator Loss: 0.3688
# Epoch 2/2... Discriminator Loss: 1.4800... Generator Loss: 0.3885
# Epoch 2/2... Discriminator Loss: 1.1960... Generator Loss: 0.7277
# Epoch 2/2... Discriminator Loss: 1.1893... Generator Loss: 0.7370
# Epoch 2/2... Discriminator Loss: 1.9136... Generator Loss: 0.1950
# Epoch 2/2... Discriminator Loss: 1.4976... Generator Loss: 0.3825
# Epoch 2/2... Discriminator Loss: 1.1315... Generator Loss: 0.7477
# Epoch 2/2... Discriminator Loss: 1.3217... Generator Loss: 0.7517
# Epoch 2/2... Discriminator Loss: 1.8142... Generator Loss: 0.2140
# Epoch 2/2... Discriminator Loss: 2.1072... Generator Loss: 0.1716
# Epoch 2/2... Discriminator Loss: 1.7874... Generator Loss: 1.3627
# Epoch 2/2... Discriminator Loss: 1.6357... Generator Loss: 0.2832
# Epoch 2/2... Discriminator Loss: 1.8296... Generator Loss: 0.2404
# Epoch 2/2... Discriminator Loss: 1.8076... Generator Loss: 0.2149

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 5.7639... Generator Loss: 0.0086
# Epoch 1/1... Discriminator Loss: 3.6493... Generator Loss: 0.0837
# Epoch 1/1... Discriminator Loss: 4.0585... Generator Loss: 0.0759
# Epoch 1/1... Discriminator Loss: 3.9284... Generator Loss: 0.1081
# Epoch 1/1... Discriminator Loss: 3.5150... Generator Loss: 0.1341
# Epoch 1/1... Discriminator Loss: 3.3659... Generator Loss: 0.1623
# Epoch 1/1... Discriminator Loss: 3.1231... Generator Loss: 0.2338
# Epoch 1/1... Discriminator Loss: 2.8598... Generator Loss: 0.2676
# Epoch 1/1... Discriminator Loss: 2.6501... Generator Loss: 0.2960
# Epoch 1/1... Discriminator Loss: 2.3659... Generator Loss: 0.4011
# Epoch 1/1... Discriminator Loss: 2.2227... Generator Loss: 0.3933
# Epoch 1/1... Discriminator Loss: 2.1213... Generator Loss: 0.4159
# Epoch 1/1... Discriminator Loss: 2.0136... Generator Loss: 0.4644
# Epoch 1/1... Discriminator Loss: 1.9565... Generator Loss: 0.4896
# Epoch 1/1... Discriminator Loss: 1.9485... Generator Loss: 0.4938
# Epoch 1/1... Discriminator Loss: 1.8835... Generator Loss: 0.5077
# Epoch 1/1... Discriminator Loss: 1.7728... Generator Loss: 0.5133
# Epoch 1/1... Discriminator Loss: 1.7649... Generator Loss: 0.5183
# Epoch 1/1... Discriminator Loss: 1.7025... Generator Loss: 0.5497
# Epoch 1/1... Discriminator Loss: 1.7230... Generator Loss: 0.5220
# Epoch 1/1... Discriminator Loss: 1.6360... Generator Loss: 0.5900
# Epoch 1/1... Discriminator Loss: 1.6479... Generator Loss: 0.5902
# Epoch 1/1... Discriminator Loss: 1.6744... Generator Loss: 0.5980
# Epoch 1/1... Discriminator Loss: 1.6523... Generator Loss: 0.5854
# Epoch 1/1... Discriminator Loss: 1.6297... Generator Loss: 0.6270
# Epoch 1/1... Discriminator Loss: 1.6438... Generator Loss: 0.5948
# Epoch 1/1... Discriminator Loss: 1.6572... Generator Loss: 0.5817
# Epoch 1/1... Discriminator Loss: 1.6270... Generator Loss: 0.5478
# Epoch 1/1... Discriminator Loss: 1.7429... Generator Loss: 0.5443
# Epoch 1/1... Discriminator Loss: 1.6282... Generator Loss: 0.5623
# Epoch 1/1... Discriminator Loss: 1.5878... Generator Loss: 0.5942
# Epoch 1/1... Discriminator Loss: 1.6520... Generator Loss: 0.5995
# Epoch 1/1... Discriminator Loss: 1.5061... Generator Loss: 0.6429
# Epoch 1/1... Discriminator Loss: 1.6146... Generator Loss: 0.6203
# Epoch 1/1... Discriminator Loss: 1.6534... Generator Loss: 0.6054
# Epoch 1/1... Discriminator Loss: 1.6997... Generator Loss: 0.5600
# Epoch 1/1... Discriminator Loss: 1.7306... Generator Loss: 0.5840
# Epoch 1/1... Discriminator Loss: 1.6574... Generator Loss: 0.5828
# Epoch 1/1... Discriminator Loss: 1.4996... Generator Loss: 0.6681
# Epoch 1/1... Discriminator Loss: 1.4234... Generator Loss: 0.6574
# Epoch 1/1... Discriminator Loss: 1.7652... Generator Loss: 0.5360
# Epoch 1/1... Discriminator Loss: 1.7600... Generator Loss: 0.5106
# Epoch 1/1... Discriminator Loss: 1.4976... Generator Loss: 0.6151
# Epoch 1/1... Discriminator Loss: 1.5009... Generator Loss: 0.6320
# Epoch 1/1... Discriminator Loss: 1.5681... Generator Loss: 0.6241
# Epoch 1/1... Discriminator Loss: 1.5964... Generator Loss: 0.5982
# Epoch 1/1... Discriminator Loss: 1.4488... Generator Loss: 0.6618
# Epoch 1/1... Discriminator Loss: 1.5202... Generator Loss: 0.6124
# Epoch 1/1... Discriminator Loss: 1.4933... Generator Loss: 0.6698
# Epoch 1/1... Discriminator Loss: 1.5541... Generator Loss: 0.6160
# Epoch 1/1... Discriminator Loss: 1.5403... Generator Loss: 0.6288
# Epoch 1/1... Discriminator Loss: 1.5425... Generator Loss: 0.6219
# Epoch 1/1... Discriminator Loss: 1.4699... Generator Loss: 0.6121
# Epoch 1/1... Discriminator Loss: 1.5476... Generator Loss: 0.6456
# Epoch 1/1... Discriminator Loss: 1.5495... Generator Loss: 0.6102
# Epoch 1/1... Discriminator Loss: 1.5235... Generator Loss: 0.5853
# Epoch 1/1... Discriminator Loss: 1.5178... Generator Loss: 0.6456
# Epoch 1/1... Discriminator Loss: 1.5536... Generator Loss: 0.6235
# Epoch 1/1... Discriminator Loss: 1.5726... Generator Loss: 0.6267
# Epoch 1/1... Discriminator Loss: 1.5144... Generator Loss: 0.6111
# Epoch 1/1... Discriminator Loss: 1.5103... Generator Loss: 0.6791
# Epoch 1/1... Discriminator Loss: 1.5605... Generator Loss: 0.5690
# Epoch 1/1... Discriminator Loss: 1.5915... Generator Loss: 0.5850
# Epoch 1/1... Discriminator Loss: 1.4961... Generator Loss: 0.6665
# Epoch 1/1... Discriminator Loss: 1.4756... Generator Loss: 0.6432
# Epoch 1/1... Discriminator Loss: 1.5892... Generator Loss: 0.6083
# Epoch 1/1... Discriminator Loss: 1.4743... Generator Loss: 0.6347
# Epoch 1/1... Discriminator Loss: 1.4701... Generator Loss: 0.6572
# Epoch 1/1... Discriminator Loss: 1.4897... Generator Loss: 0.6473
# Epoch 1/1... Discriminator Loss: 1.5364... Generator Loss: 0.6214
# Epoch 1/1... Discriminator Loss: 1.4941... Generator Loss: 0.6280
# Epoch 1/1... Discriminator Loss: 1.4721... Generator Loss: 0.7070
# Epoch 1/1... Discriminator Loss: 1.4661... Generator Loss: 0.6784
# Epoch 1/1... Discriminator Loss: 1.4370... Generator Loss: 0.6799
# Epoch 1/1... Discriminator Loss: 1.5417... Generator Loss: 0.6218
# Epoch 1/1... Discriminator Loss: 1.3506... Generator Loss: 0.7463
# Epoch 1/1... Discriminator Loss: 1.5762... Generator Loss: 0.5987
# Epoch 1/1... Discriminator Loss: 1.5197... Generator Loss: 0.6579
# Epoch 1/1... Discriminator Loss: 1.4358... Generator Loss: 0.6112
# Epoch 1/1... Discriminator Loss: 1.5529... Generator Loss: 0.6468
# Epoch 1/1... Discriminator Loss: 1.4522... Generator Loss: 0.6259
# Epoch 1/1... Discriminator Loss: 1.5010... Generator Loss: 0.6503
# Epoch 1/1... Discriminator Loss: 1.5899... Generator Loss: 0.5702
# Epoch 1/1... Discriminator Loss: 1.4604... Generator Loss: 0.6880
# Epoch 1/1... Discriminator Loss: 1.4384... Generator Loss: 0.6455
# Epoch 1/1... Discriminator Loss: 1.5266... Generator Loss: 0.6280
# Epoch 1/1... Discriminator Loss: 1.5590... Generator Loss: 0.6035
# Epoch 1/1... Discriminator Loss: 1.4307... Generator Loss: 0.6626
# Epoch 1/1... Discriminator Loss: 1.5232... Generator Loss: 0.6147
# Epoch 1/1... Discriminator Loss: 1.5534... Generator Loss: 0.6122
# Epoch 1/1... Discriminator Loss: 1.5018... Generator Loss: 0.6622
# Epoch 1/1... Discriminator Loss: 1.5207... Generator Loss: 0.6766
# Epoch 1/1... Discriminator Loss: 1.5826... Generator Loss: 0.6198
# Epoch 1/1... Discriminator Loss: 1.5910... Generator Loss: 0.6149
# Epoch 1/1... Discriminator Loss: 1.5340... Generator Loss: 0.6174
# Epoch 1/1... Discriminator Loss: 1.5348... Generator Loss: 0.6365
# Epoch 1/1... Discriminator Loss: 1.4289... Generator Loss: 0.6817
# Epoch 1/1... Discriminator Loss: 1.5365... Generator Loss: 0.6212
# Epoch 1/1... Discriminator Loss: 1.4649... Generator Loss: 0.6298
# Epoch 1/1... Discriminator Loss: 1.4686... Generator Loss: 0.6415
# Epoch 1/1... Discriminator Loss: 1.5884... Generator Loss: 0.5906
# Epoch 1/1... Discriminator Loss: 1.4125... Generator Loss: 0.6707
# Epoch 1/1... Discriminator Loss: 1.5359... Generator Loss: 0.6317
# Epoch 1/1... Discriminator Loss: 1.4523... Generator Loss: 0.6715
# Epoch 1/1... Discriminator Loss: 1.5511... Generator Loss: 0.6239
# Epoch 1/1... Discriminator Loss: 1.4745... Generator Loss: 0.6106
# Epoch 1/1... Discriminator Loss: 1.4640... Generator Loss: 0.6397
# Epoch 1/1... Discriminator Loss: 1.4082... Generator Loss: 0.6935
# Epoch 1/1... Discriminator Loss: 1.4762... Generator Loss: 0.6247
# Epoch 1/1... Discriminator Loss: 1.4836... Generator Loss: 0.6658
# Epoch 1/1... Discriminator Loss: 1.5141... Generator Loss: 0.6493
# Epoch 1/1... Discriminator Loss: 1.4538... Generator Loss: 0.6682
# Epoch 1/1... Discriminator Loss: 1.4547... Generator Loss: 0.6451
# Epoch 1/1... Discriminator Loss: 1.4679... Generator Loss: 0.6506
# Epoch 1/1... Discriminator Loss: 1.4760... Generator Loss: 0.6707
# Epoch 1/1... Discriminator Loss: 1.4177... Generator Loss: 0.6638
# Epoch 1/1... Discriminator Loss: 1.5023... Generator Loss: 0.6414
# Epoch 1/1... Discriminator Loss: 1.5023... Generator Loss: 0.6268
# Epoch 1/1... Discriminator Loss: 1.4043... Generator Loss: 0.6715
# Epoch 1/1... Discriminator Loss: 1.5036... Generator Loss: 0.6176
# Epoch 1/1... Discriminator Loss: 1.3953... Generator Loss: 0.6850
# Epoch 1/1... Discriminator Loss: 1.4666... Generator Loss: 0.6691
# Epoch 1/1... Discriminator Loss: 1.4076... Generator Loss: 0.6749
# Epoch 1/1... Discriminator Loss: 1.4650... Generator Loss: 0.6095
# Epoch 1/1... Discriminator Loss: 1.4528... Generator Loss: 0.6978
# Epoch 1/1... Discriminator Loss: 1.4517... Generator Loss: 0.6579
# Epoch 1/1... Discriminator Loss: 1.5144... Generator Loss: 0.6200
# Epoch 1/1... Discriminator Loss: 1.4612... Generator Loss: 0.6458
# Epoch 1/1... Discriminator Loss: 1.5493... Generator Loss: 0.6605
# Epoch 1/1... Discriminator Loss: 1.5062... Generator Loss: 0.6307
# Epoch 1/1... Discriminator Loss: 1.4627... Generator Loss: 0.6885
# Epoch 1/1... Discriminator Loss: 1.4721... Generator Loss: 0.6515
# Epoch 1/1... Discriminator Loss: 1.4215... Generator Loss: 0.6699
# Epoch 1/1... Discriminator Loss: 1.4085... Generator Loss: 0.6453
# Epoch 1/1... Discriminator Loss: 1.5024... Generator Loss: 0.6677
# Epoch 1/1... Discriminator Loss: 1.4936... Generator Loss: 0.6667
# Epoch 1/1... Discriminator Loss: 1.4390... Generator Loss: 0.6398
# Epoch 1/1... Discriminator Loss: 1.4647... Generator Loss: 0.6653
# Epoch 1/1... Discriminator Loss: 1.4809... Generator Loss: 0.6150
# Epoch 1/1... Discriminator Loss: 1.4698... Generator Loss: 0.6466
# Epoch 1/1... Discriminator Loss: 1.4942... Generator Loss: 0.6405
# Epoch 1/1... Discriminator Loss: 1.4721... Generator Loss: 0.6501
# Epoch 1/1... Discriminator Loss: 1.5274... Generator Loss: 0.6460
# Epoch 1/1... Discriminator Loss: 1.4942... Generator Loss: 0.6015
# Epoch 1/1... Discriminator Loss: 1.3985... Generator Loss: 0.6547
# Epoch 1/1... Discriminator Loss: 1.4653... Generator Loss: 0.6334
# Epoch 1/1... Discriminator Loss: 1.5452... Generator Loss: 0.6039
# Epoch 1/1... Discriminator Loss: 1.4976... Generator Loss: 0.6481
# Epoch 1/1... Discriminator Loss: 1.5075... Generator Loss: 0.6152
# Epoch 1/1... Discriminator Loss: 1.4328... Generator Loss: 0.6872
# Epoch 1/1... Discriminator Loss: 1.4529... Generator Loss: 0.6832
# Epoch 1/1... Discriminator Loss: 1.4620... Generator Loss: 0.6704
# Epoch 1/1... Discriminator Loss: 1.6303... Generator Loss: 0.5934
# Epoch 1/1... Discriminator Loss: 1.4613... Generator Loss: 0.6380
# Epoch 1/1... Discriminator Loss: 1.4764... Generator Loss: 0.6437
# Epoch 1/1... Discriminator Loss: 1.3471... Generator Loss: 0.7413
# Epoch 1/1... Discriminator Loss: 1.5231... Generator Loss: 0.6046
# Epoch 1/1... Discriminator Loss: 1.4676... Generator Loss: 0.6233

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
